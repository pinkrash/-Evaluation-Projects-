# %% [markdown]
# # BASEBALL WINNING PREDICTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball_dataset')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [raw]
#  There is no null value in this data set.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
# summary
#
# 1. some columns are skewed and some are normal distributed.
# 2. observing maximum point of columns its clear that some columns have outliers.
# 3.columns like SO,RA and BB have high variance.

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.scatterplot(x='W',y=i,data=df)
        plt.xlabel("Wins")
        plt.ylabel(i)
    p+=1
    
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.regplot(x=df['W'],y=df[i])
        plt.xlabel("Wins")
        plt.ylabel(i)
    p+=1
    
plt.show()

# %% [raw]
# As we can see some features have positive relation, some have negative relation and some have no relation with target like
# ER,ERA and RA.

# %%
cor=df.corr()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
df.drop(['ERA','RA'],axis=1,inplace=True)

# %% [raw]
# RA,ER and ERA have high correlation also negative linear relation with target.
# so we have to drop some columns.

# %%
plt.figure(figsize=(10,20))
p=1
for i in df:
    if p<=16:
        plt.subplot(5,4,p)
        sns.boxplot(df[i])
        plt.xlabel(i)
        
    p+=1
    
plt.show()

# %% [raw]
# Some outliers are present in some columns.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df[['SHO','SV','E','R']]))
z
# Out:
#          SHO        SV         E         R
# 0   0.814629  1.671607  0.461470  0.619078
# 1   0.172800  0.249879  0.607197  0.134432
# 2   0.320914  0.654856  1.117242  0.332906
# 3   0.567771  0.784104  0.485758  1.146419
# 4   0.172800  1.042600  0.607197  0.013270
# 5   0.320914  1.171848  0.461470  3.509647
# 6   1.802057  0.637623  0.097152  1.311430
# 7   0.320914  0.008617  1.262970  0.428681
# 8   0.172800  2.188598  0.048576  0.765626
# 9   0.320914  0.396360  0.194303  1.034489
# 10  0.567771  0.249879  1.797303  1.086415
# 11  0.419657  0.525608  0.680061  0.705622
# 12  0.172800  0.379127  0.097152  0.471376
# 13  0.172800  0.249879  0.024288  0.557920
# 14  0.913371  1.947335  2.307348  0.099814
# 15  0.913371  2.447094  0.121439  0.713699
# 16  0.419657  1.413111  2.015894  0.151740
# 17  2.394514  0.637623  1.214394  0.013270
# 18  1.061486  0.396360  1.578712  0.575229
# 19  0.814629  1.042600  0.315742  0.834861
# 20  0.666514  0.896119  0.461470  0.090583
# ...

# %%
df1 = df[(z<3).all(axis=1)]
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   ER  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104  601   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70  653   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  584  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68  643   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83  746   7   12  35   86
# 6    87  764  5567  1397  272  19  212  554  1227   63  652   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44  646   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87  604   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71  694   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101  680   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121  572   5   13  39   85
# ...

# %%
df1.shape
# Out:
# (29, 15)

# %% [raw]
# After removing outliers we have not lost so much data.

# %%
x=df1.iloc[:,1:]
y=df1.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %% [raw]
# We have to scaled the data as it has variance present inside it. so it will be scaled for training and testing.

# %%
st=StandardScaler()
x=pd.DataFrame(st.fit_transform(x))

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3,random_state=42)

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
pred=lr.predict(xtest)

# %%
print(mean_squared_error(ytest,pred))
print(mean_absolute_error(ytest,pred))
print(r2_score(ytest,pred))
# Out:
# 10.147478052288815
# 2.456531148540288
# 0.8964803876277841

# %%
ls=Lasso()
ls.fit(xtrain,ytrain)
predi=ls.predict(xtest)

# %%
print(mean_squared_error(ytest,predi))
print(mean_absolute_error(ytest,predi))
print(r2_score(ytest,predi))
# Out:
# 23.4997081373157
# 3.8367078886176325
# 0.7602674610676862

# %%
knn=KNeighborsClassifier()
knn.fit(xtrain,ytrain)
predic=knn.predict(xtest)

# %%
print(mean_squared_error(ytest,predic))
print(mean_absolute_error(ytest,predic))
print(r2_score(ytest,predic))
# Out:
# 173.66666666666666
# 11.444444444444445
# -0.771662468513854

# %%
svr=SVR()
svr.fit (xtrain,ytrain)
PRED=svr.predict(xtest)

# %%
print(mean_squared_error(ytest,PRED))
print(mean_absolute_error(ytest,PRED))
print(r2_score(ytest,PRED))
# Out:
# 91.98892370171855
# 8.383558329735017
# 0.06157395216130945

# %%
dtc=DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
PRE=dtc.predict(xtest)

# %%
print(mean_squared_error(ytest,PRE))
print(mean_absolute_error(ytest,PRE))
print(r2_score(ytest,PRE))
# Out:
# 100.0
# 8.666666666666666
# -0.02015113350125941

# %% [raw]
# Best model for base ball dataset winning prediction is Linear Regression.

# %%
plt.figure(figsize=(4,4))
sns.regplot(x=ytest,y=pred,color='r')
plt.xlabel('Actual Win',fontsize=15)
plt.ylabel('Prediction',fontsize=15)
plt.title("Linear Regressor Regressor")
plt.show()

# %%
AS we can see from above plot acuuracy is high with Linear Regression model.
